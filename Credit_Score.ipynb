# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Загрузим данные и посмотрим на первые 20 строк

data = pd.read_csv('C:\\Games\\Datasets\\Test\\data.csv', sep = ';')
data.head(20)
# Out:
#     closed_cred_sum  closed_creds  active_cred_sum_overdue  active_cred_sum  \
# 0         143822.00            22                   104.12        130068.80
# 1              0.00             0                 38151.93         46230.00
# 2          51356.00             2                  3000.00          3000.00
# 3              0.00             0                 22784.19         32103.52
# 4          12298.00             1                  4942.95          4950.00
# 5         786916.00            11                     0.00       1063763.00
# 6         786916.00            11                     0.00       1063763.00
# 7         786916.00            11                     0.00       1063763.00
# 8         786916.00            11                     0.00       1063763.00
# 9              0.00             0                 21143.00         21143.00
# 10             0.00             0                 21143.00         21143.00
# 11        937276.13            17                 11577.24        819686.00
# 12             0.00             0                     0.00          8000.00
# 13             0.00             0                     0.00          8000.00
# 14             0.00             0                     0.00          8000.00
# 15             0.00             0                     0.00          8000.00
# 16         14000.00             3                 54529.24        433628.68
# 17          3600.00             4                     0.00         62471.05
# 18          3600.00             4                     0.00         62471.05
# 19          3600.00             4                     0.00         62471.05
#
#     active_cred_day_overdue  active_cred_max_overdue  age  gender  region  \
# 0                         8                   756.09   31       0      36
# 1                      1492                 38151.93   51       0      93
# 2                         8                  3000.00   28       1       3
# 3                       913                 22784.19   28       0      52
# 4                      2883                  4942.95   31       0      47
# 5                         0                 10395.39   47       0      38
# 6                         0                 10395.39   47       0      38
# 7                         0                 10395.39   47       0      38
# 8                         0                 10395.39   47       0      38
# 9                      1016                 10924.00   28       1       0
# 10                     1016                 10924.00   28       1       0
# 11                       19                 11577.24   47       0      47
# 12                        0                     0.00   24       1      80
# 13                        0                     0.00   24       1      80
# 14                        0                     0.00   24       1      80
# 15                        0                     0.00   24       1      80
# 16                      839                 10000.00   35       0       0
# 17                        0                  3605.92   23       0      24
# 18                        0                  3605.92   23       0      24
# 19                        0                  3605.92   23       0      24
#
#     first_loan  loan_cost_all  first_days_quant  month_income  order_date  \
# 0      10000.0          10000               196           0.0  2017-07-23
# 1      10000.0          10000                17       20000.0  2017-07-23
# 2      10000.0          10000                84           0.0  2017-07-23
# 3      10000.0          10000                 7           0.0  2017-07-23
# 4       5000.0           5000                20           0.0  2017-07-23
# 5      10000.0           5500                14       50000.0  2017-07-23
# 6      10000.0           5500                14       50000.0  2017-07-23
# 7      10000.0           5500                14       50000.0  2017-07-23
# 8      10000.0           5500                14       50000.0  2017-07-23
# 9      10000.0          10000                90           0.0  2017-07-23
# 10     10000.0          10000                15       30000.0  2017-07-23
# 11     31000.0          20000                20       60000.0  2017-07-23
# 12      7000.0           7000                10       35000.0  2017-07-23
# 13      7000.0           7000                10       35000.0  2017-07-23
# 14      7000.0           7000                10       35000.0  2017-07-23
# 15      7000.0           7000                10       35000.0  2017-07-23
# 16      3000.0           3000                20       35000.0  2017-07-23
# 17      2000.0           2000                19       20000.0  2017-07-23
# 18      2000.0           2000                19       20000.0  2017-07-23
# 19      2000.0           2000                19       20000.0  2017-07-23
#
#     cost_all  order_id  client_id  expert
# 0        0.0    728319     320464       1
# 1        0.0    728321     320466       1
# 2        0.0    728323     320467       1
# 3        0.0    728447     320533       1
# 4        0.0    728421     298598       1
# 5        0.0    728526     320564       0
# 6        0.0    728526     320564       0
# 7        0.0    728526     320564       0
# 8        0.0    728526     320564       0
# 9        0.0    728454     123851       1
# 10       0.0    728553     123851       1
# 11   52960.0    728474     166827       0
# 12       0.0    728476     320544       1
# 13       0.0    728478     320544       1
# 14       0.0    728476     320544       1
# 15       0.0    728478     320544       1
# 16       0.0    728541     320570       1
# 17       0.0    728506     320559       1
# 18       0.0    728506     320559       1
# 19       0.0    728506     320559       1

# %%
# Первое, на что сразу мы можем обратить внимание - наличие дубликатов в данном наборе. Узнаем объем выборки

data.shape
# Out:
# (50001, 18)

# %%
# Избавимся от дубликатов

data.drop_duplicates(inplace = True)

# %%
# И убедимся в том, что объем выборки существенно сократился

data.shape
# Out:
# (42943, 18)

# %%
# Посмотрим на данные еще раз
# Невооруженным глазом можно заметить, что количественные переменные варьируются в очень широком диапазоне значений

data.head(20)
# Out:
#     closed_cred_sum  closed_creds  active_cred_sum_overdue  active_cred_sum  \
# 0         143822.00            22                   104.12        130068.80
# 1              0.00             0                 38151.93         46230.00
# 2          51356.00             2                  3000.00          3000.00
# 3              0.00             0                 22784.19         32103.52
# 4          12298.00             1                  4942.95          4950.00
# 5         786916.00            11                     0.00       1063763.00
# 9              0.00             0                 21143.00         21143.00
# 10             0.00             0                 21143.00         21143.00
# 11        937276.13            17                 11577.24        819686.00
# 12             0.00             0                     0.00          8000.00
# 13             0.00             0                     0.00          8000.00
# 16         14000.00             3                 54529.24        433628.68
# 17          3600.00             4                     0.00         62471.05
# 20         15189.00             2                     0.00             0.00
# 21             0.00             0                185600.08        210575.25
# 22         45000.00             7                  3000.00         18000.00
# 23         36990.00             5                     0.00             0.00
# 24             0.00             0                  3208.70         15000.00
# 25          4000.00             2                 12877.98         42086.00
# 26        165000.00            13                     0.00             0.00
#
#     active_cred_day_overdue  active_cred_max_overdue  age  gender  region  \
# 0                         8                   756.09   31       0      36
# 1                      1492                 38151.93   51       0      93
# 2                         8                  3000.00   28       1       3
# 3                       913                 22784.19   28       0      52
# 4                      2883                  4942.95   31       0      47
# 5                         0                 10395.39   47       0      38
# 9                      1016                 10924.00   28       1       0
# 10                     1016                 10924.00   28       1       0
# 11                       19                 11577.24   47       0      47
# 12                        0                     0.00   24       1      80
# 13                        0                     0.00   24       1      80
# 16                      839                 10000.00   35       0       0
# 17                        0                  3605.92   23       0      24
# 20                        0                     0.00   26       0       0
# 21                     3998                138692.99   34       1      80
# 22                      525                 10000.00   22       1      45
# 23                        0                     0.00   28       0      52
# 24                       25                  3256.67   21       0      60
# 25                     1243                 16076.27   38       0       0
# 26                        0                     0.00   57       0       0
#
#     first_loan  loan_cost_all  first_days_quant  month_income  order_date  \
# 0      10000.0          10000               196           0.0  2017-07-23
# 1      10000.0          10000                17       20000.0  2017-07-23
# 2      10000.0          10000                84           0.0  2017-07-23
# 3      10000.0          10000                 7           0.0  2017-07-23
# 4       5000.0           5000                20           0.0  2017-07-23
# 5      10000.0           5500                14       50000.0  2017-07-23
# 9      10000.0          10000                90           0.0  2017-07-23
# 10     10000.0          10000                15       30000.0  2017-07-23
# 11     31000.0          20000                20       60000.0  2017-07-23
# 12      7000.0           7000                10       35000.0  2017-07-23
# 13      7000.0           7000                10       35000.0  2017-07-23
# 16      3000.0           3000                20       35000.0  2017-07-23
# 17      2000.0           2000                19       20000.0  2017-07-23
# 20      5000.0           5000                17       50000.0  2017-07-23
# 21     10000.0          10000                20       35000.0  2017-07-23
# 22      7000.0           7000                10       35000.0  2017-07-23
# 23      4000.0           2000                10       35000.0  2017-07-23
# 24      4000.0           4000                10       35000.0  2017-07-23
# 25      2000.0           2000                 8       20000.0  2017-07-23
# 26      2000.0           2000                 7       30000.0  2017-07-23
#
#     cost_all  order_id  client_id  expert
# 0        0.0    728319     320464       1
# 1        0.0    728321     320466       1
# 2        0.0    728323     320467       1
# 3        0.0    728447     320533       1
# 4        0.0    728421     298598       1
# 5        0.0    728526     320564       0
# 9        0.0    728454     123851       1
# 10       0.0    728553     123851       1
# 11   52960.0    728474     166827       0
# 12       0.0    728476     320544       1
# 13       0.0    728478     320544       1
# 16       0.0    728541     320570       1
# 17       0.0    728506     320559       1
# 20       0.0    728462     277265       1
# 21       0.0    728537     320568       1
# 22       0.0    728500     238453       1
# 23    2654.0    728488     140916       0
# 24       0.0    728545     320572       1
# 25    2612.8    728542      90182       0
# 26    2305.2    728544     124621       0

# %%
# Создадим список количественных переменных
# В него не включены 'age', 'loan_cost_all' и 'cost_all', с ними разберемся отдельно позже

num_columns = ['closed_cred_sum', 'closed_creds', 'active_cred_sum_overdue', 'active_cred_sum', 'active_cred_day_overdue', 
              'active_cred_max_overdue', 'first_loan', 'first_days_quant', 'month_income']

# %%
# Оценим значения средних и медиан для количественных переменных
# У шести переменных, характеризующих кредитную историю клиента, значения статистик сильно разнятся
# Можем сделать быстрый вывод о том, что их распределения не являются нормальными

for i in num_columns:
    print(i, '-' , round(data[i].mean(), 2), '|', round(data[i].median(), 2))
# Out:
# closed_cred_sum - 179966.45 | 39835.0
# closed_creds - 7.84 | 3.0
# active_cred_sum_overdue - 49786.39 | 5000.0
# active_cred_sum - 188713.26 | 54430.82
# active_cred_day_overdue - 703.1 | 61.0
# active_cred_max_overdue - 36453.47 | 6431.0
# first_loan - 7725.3 | 7000.0
# first_days_quant - 24.16 | 20.0
# month_income - 25514.71 | 26000.0

# %%
# Посмотрим отдельно на оставшиеся переменные из списка num_columns

sns.boxplot(data['first_loan'])
# Out:
# <AxesSubplot:xlabel='first_loan'>

# %%
# Казалось бы, исходя из графиков можем наблюдать большое количество выбросов, но следуя логике нужно понимать, что они не
# являются ошибками измерений, наши переменные действительно так распределены

sns.boxplot(data['first_days_quant'])
# Out:
# <AxesSubplot:xlabel='first_days_quant'>

# %%
# Таким образом, впоследствии, к переменным из списка num_columns применим силовое преобразование, 
# а также стандартизацию, когда будем формировать конвейер

sns.boxplot(data['month_income'])
# Out:
# <AxesSubplot:xlabel='month_income'>

# %%
# В наших данных практически нет пропущенных значений,
# лишь в переменной 'first_loan' присутствует совсем малое количество пропусков

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42943 entries, 0 to 50000
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   closed_cred_sum          42943 non-null  float64
#  1   closed_creds             42943 non-null  int64
#  2   active_cred_sum_overdue  42943 non-null  float64
#  3   active_cred_sum          42943 non-null  float64
#  4   active_cred_day_overdue  42943 non-null  int64
#  5   active_cred_max_overdue  42943 non-null  float64
#  6   age                      42943 non-null  int64
#  7   gender                   42943 non-null  int64
#  8   region                   42943 non-null  int64
#  9   first_loan               42926 non-null  float64
#  10  loan_cost_all            42943 non-null  int64
#  11  first_days_quant         42943 non-null  int64
#  12  month_income             42943 non-null  float64
#  13  order_date               42943 non-null  object
#  14  cost_all                 42943 non-null  float64
#  15  order_id                 42943 non-null  int64
#  16  client_id                42943 non-null  int64
#  17  expert                   42943 non-null  int64
# dtypes: float64(7), int64(10), object(1)
# memory usage: 6.2+ MB

# %%
# Посмотрим на целевую переменную
# Имеем задачу бинарной классификации с дисбалансом классов 

sns.countplot(data['expert'])
# Out:
# <AxesSubplot:xlabel='expert', ylabel='count'>

# %%
# К переменной возраста в конвейре применим биннинг, разбив ее на группы

sns.displot(data['age'])

# %%
# Категориальную переменную пол оставляем как есть, впоследствии все категориальные переменные мы закодируем

sns.countplot(data['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
# В переменной регион нам встречается значение "0", более того очень большое кол-во раз
# Регион равный нулю можно расценивать как пропуск, тогда мы имеем переменную с огромным кол-вом пропусков и почти сотней разных
# вариантов значений, среди которых также присутствуют еще и редкие категории
# Переменная будет слишком сложной для обработки в модели, перед разбиением на тренировочную и тестовую выборки избавимся от нее

data['region'].value_counts()
# Out:
# 0     17605
# 40     3668
# 36     1594
# 75     1524
# 65     1320
#       ...
# 48       15
# 43       13
# 85       13
# 21        8
# 9         5
# Name: region, Length: 99, dtype: int64

# %%
# Как мы помним в переменной 'first_loan' присутствует немного пропусков
# Можно заметить ее взаимосвязь с 'loan_cost_all' и увидеть, что в более, чем ~80% случаев они равны 

data.query("first_loan == loan_cost_all")['first_loan'].count()/data.shape[0]
# Out:
# 0.8166639498870596

# %%
# Заполним пропуски значением "0"

data['first_loan'].fillna(0, inplace = True)

# %%
# Посмотрим на срез данных

data.query('first_loan == 0')
# Out:
#        closed_cred_sum  closed_creds  active_cred_sum_overdue  \
# 184         2722669.00            59                     0.00
# 7150         765963.00             8                589946.45
# 8848          23500.00             4                 12594.87
# 13176         24000.00             3                  2230.20
# 13461        934734.29            97                     0.00
# 13581             0.00             0                 15000.00
# 24461       1653801.90           117                255644.29
# 30659          5337.00             1                 37124.07
# 31243         62709.00             7                 50641.35
# 32363        129000.00             4                 73506.93
# 36312          6001.66             3                  3000.00
# 37694         21320.00             1                     0.00
# 40064             0.00             0                  8635.65
# 41776             0.00             0                 14104.71
# 48434        203882.00            11                 18565.19
# 49752          1000.00             1                  3000.00
# 49839         28600.00             1                 68918.47
#
#        active_cred_sum  active_cred_day_overdue  active_cred_max_overdue  age  \
# 184          891500.00                        0                  8956.61   57
# 7150        1025000.00                     4418                259317.43   53
# 8848         287250.00                      282                  8500.00   22
# 13176          3000.00                        5                  2230.20   22
# 13461        307449.02                        0                   764.82   25
# 13581         15000.00                      137                 15000.00   18
# 24461        672187.99                     2744                 60076.09   36
# 30659         38567.00                     1435                 37124.07   25
# 31243         67496.00                     3579                 45027.00   36
# 32363         83500.00                     4801                 47506.93   31
# 36312         31800.00                       42                 21283.42   26
# 37694        214271.11                        0                     0.00   55
# 40064         19000.00                      237                  4635.65   22
# 41776         36541.00                      105                 14104.71   21
# 48434        115500.00                      154                 10025.24   43
# 49752          4000.00                       30                  3000.00   24
# 49839         68918.47                     1177                 52918.47   22
#
#        gender  region  first_loan  loan_cost_all  first_days_quant  \
# 184         0      40         0.0          10000                10
# 7150        0      40         0.0           2000                20
# 8848        0      40         0.0           2000                20
# 13176       0       0         0.0           2000                20
# 13461       1       0         0.0           2500                20
# 13581       0      78         0.0           2000                20
# 24461       1       4         0.0           2000                20
# 30659       0      65         0.0           2000                20
# 31243       0      78         0.0           2000                20
# 32363       0      78         0.0           1000                23
# 36312       1      75         0.0           2000                20
# 37694       1      75         0.0           1500                20
# 40064       1       0         0.0              0                 0
# 41776       1       0         0.0           1000                23
# 48434       1       0         0.0           3000                20
# 49752       0       0         0.0           2000                20
# 49839       1      68         0.0           2000                20
#
#        month_income  order_date  cost_all  order_id  client_id  expert
# 184         87000.0  2017-07-25       0.0    730831     183863       1
# 7150        40000.0  2017-07-01       0.0    702433     306898       1
# 8848        42000.0  2017-07-03       0.0    705194     214622       1
# 13176       25000.0  2017-07-08       0.0    711678     197369       1
# 13461       50000.0  2017-07-08    3590.0    712046     231691       0
# 13581       30000.0  2017-07-08       0.0    712179     227008       1
# 24461       40000.0  2017-07-24       0.0    729540     236614       1
# 30659       25000.0  2017-07-30       0.0    738690     149577       1
# 31243       26000.0  2017-07-31       0.0    740962     309289       1
# 32363       45000.0  2017-07-31    1501.4    741054     324256       0
# 36312       19000.0  2017-08-03       0.0    745489     330138       1
# 37694       20000.0  2017-08-04       0.0    746842     330888       0
# 40064       25000.0  2017-08-06       0.0    749408     141866       1
# 41776       35000.0  2017-08-07       0.0    751213     333390       0
# 48434       31000.0  2017-08-12       0.0    757923     131328       0
# 49752       40000.0  2017-08-13       0.0    759402     338197       1
# 49839       25000.0  2017-08-13       0.0    759459     246973       1

# %%
# И заполним все пропущенные значения(нули) соответствующими им значениями из переменной 'loan_cost_all'

data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 10000), 'first_loan'] = 10000
data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 2000), 'first_loan'] = 2000
data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 2500), 'first_loan'] = 2500
data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 1000), 'first_loan'] = 1000
data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 1500), 'first_loan'] = 1500
data.loc[(data['first_loan'] == 0) & (data['loan_cost_all'] == 3000), 'first_loan'] = 3000

# %%
data['first_loan'].isna().sum()
# Out:
# 0

# %%
# Обратим еще раз внимание на взаимосвязь переменных 'first_loan' и 'loan_cost_all'
# Более 90% данных подчиняются правилу, что при равенстве этих двух переменных целевая 'expert' равна "1" и равна "0", 
# если переменные не равны (лик в данных, от которого мы избавимся перед обучением модели, хотя если бы речь шла 
# о соревновательных целях, мы бы конечно его использовали)

data.query("(first_loan == loan_cost_all) & (expert == 1)")['first_loan'].count()/data.shape[0]
# Out:
# 0.7364646158861747

# %%
data.query("(first_loan != loan_cost_all) & (expert == 0)")['first_loan'].count()/data.shape[0]
# Out:
# 0.18089094846657197

# %%
# Рассмотрим переменную дата

data['order_date'] = pd.to_datetime(data['order_date'])

# %%
# Вычленим из нее год и месяц и посмотрим на графики

data['Year'] = data['order_date'].apply(lambda x: x.year)

# %%
sns.countplot(data['Year'], hue = data['expert'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
data['Month'] = data['order_date'].apply(lambda x: x.month)

# %%
# Общая тенденция распределения целевой переменной сохраняется независимо от даты
# От даты можно будет избавиться перед разбиением на тренировочную и тестовую выборки

sns.countplot(data['Month'], hue = data['expert'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
# Видим, что в переменной 'cost_all' подавляющее большинство значений равно нулю

sns.displot(data['cost_all'])

# %%
# Преобразуем ее, чтобы она принимала значения только "1" или "0"

data.loc[data['cost_all'] != 0, 'cost_all'] = 1

# %%
data['cost_all'].value_counts()
# Out:
# 0.0    34548
# 1.0     8395
# Name: cost_all, dtype: int64

# %%
num_columns = ['closed_cred_sum', 'closed_creds', 'active_cred_sum_overdue', 'active_cred_sum', 'active_cred_day_overdue', 
              'active_cred_max_overdue', 'first_loan', 'first_days_quant', 'month_income']

# %%
# Подготовим датасэт для обучения, убрав из него ненужные переменные

data_pre = data.drop(['region', 'order_date', 'order_id', 'client_id', 'loan_cost_all', 'Year', 'Month'], axis = 1)

# %%
data_pre.head(20)
# Out:
#     closed_cred_sum  closed_creds  active_cred_sum_overdue  active_cred_sum  \
# 0         143822.00            22                   104.12        130068.80
# 1              0.00             0                 38151.93         46230.00
# 2          51356.00             2                  3000.00          3000.00
# 3              0.00             0                 22784.19         32103.52
# 4          12298.00             1                  4942.95          4950.00
# 5         786916.00            11                     0.00       1063763.00
# 9              0.00             0                 21143.00         21143.00
# 10             0.00             0                 21143.00         21143.00
# 11        937276.13            17                 11577.24        819686.00
# 12             0.00             0                     0.00          8000.00
# 13             0.00             0                     0.00          8000.00
# 16         14000.00             3                 54529.24        433628.68
# 17          3600.00             4                     0.00         62471.05
# 20         15189.00             2                     0.00             0.00
# 21             0.00             0                185600.08        210575.25
# 22         45000.00             7                  3000.00         18000.00
# 23         36990.00             5                     0.00             0.00
# 24             0.00             0                  3208.70         15000.00
# 25          4000.00             2                 12877.98         42086.00
# 26        165000.00            13                     0.00             0.00
#
#     active_cred_day_overdue  active_cred_max_overdue  age  gender  first_loan  \
# 0                         8                   756.09   31       0     10000.0
# 1                      1492                 38151.93   51       0     10000.0
# 2                         8                  3000.00   28       1     10000.0
# 3                       913                 22784.19   28       0     10000.0
# 4                      2883                  4942.95   31       0      5000.0
# 5                         0                 10395.39   47       0     10000.0
# 9                      1016                 10924.00   28       1     10000.0
# 10                     1016                 10924.00   28       1     10000.0
# 11                       19                 11577.24   47       0     31000.0
# 12                        0                     0.00   24       1      7000.0
# 13                        0                     0.00   24       1      7000.0
# 16                      839                 10000.00   35       0      3000.0
# 17                        0                  3605.92   23       0      2000.0
# 20                        0                     0.00   26       0      5000.0
# 21                     3998                138692.99   34       1     10000.0
# 22                      525                 10000.00   22       1      7000.0
# 23                        0                     0.00   28       0      4000.0
# 24                       25                  3256.67   21       0      4000.0
# 25                     1243                 16076.27   38       0      2000.0
# 26                        0                     0.00   57       0      2000.0
#
#     first_days_quant  month_income  cost_all  expert
# 0                196           0.0       0.0       1
# 1                 17       20000.0       0.0       1
# 2                 84           0.0       0.0       1
# 3                  7           0.0       0.0       1
# 4                 20           0.0       0.0       1
# 5                 14       50000.0       0.0       0
# 9                 90           0.0       0.0       1
# 10                15       30000.0       0.0       1
# 11                20       60000.0       1.0       0
# 12                10       35000.0       0.0       1
# 13                10       35000.0       0.0       1
# 16                20       35000.0       0.0       1
# 17                19       20000.0       0.0       1
# 20                17       50000.0       0.0       1
# 21                20       35000.0       0.0       1
# 22                10       35000.0       0.0       1
# 23                10       35000.0       1.0       0
# 24                10       35000.0       0.0       1
# 25                 8       20000.0       1.0       0
# 26                 7       30000.0       1.0       0

# %%
# Большое влияние на целевую переменную оказывает 'cost_all'

sns.heatmap(data_pre.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data_pre[['cost_all', 'expert']].corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
# Избавимся также и от этой переменной перед разбиением на тренировочную/тестовую выборки

data_pre.drop(['cost_all'], axis = 1, inplace = True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42943 entries, 0 to 50000
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   closed_cred_sum          42943 non-null  float64
#  1   closed_creds             42943 non-null  int64
#  2   active_cred_sum_overdue  42943 non-null  float64
#  3   active_cred_sum          42943 non-null  float64
#  4   active_cred_day_overdue  42943 non-null  int64
#  5   active_cred_max_overdue  42943 non-null  float64
#  6   age                      42943 non-null  int64
#  7   gender                   42943 non-null  int64
#  8   first_loan               42943 non-null  float64
#  9   first_days_quant         42943 non-null  int64
#  10  month_income             42943 non-null  float64
#  11  expert                   42943 non-null  int64
# dtypes: float64(6), int64(6)
# memory usage: 5.5 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import StandardScaler

# %%
# Разбиваем данные на тренировочную и тестовую выборки

X_train, X_test, y_train, y_test = train_test_split(data_pre.drop('expert', axis = 1), 
                                                    data_pre['expert'], 
                                                    random_state = 42)

# %%
# Создаем списки переменных

cat_columns = ['gender']
num_columns = ['closed_cred_sum', 'closed_creds', 'active_cred_sum_overdue', 'active_cred_sum', 'active_cred_day_overdue', 
              'active_cred_max_overdue', 'first_loan', 'first_days_quant', 'month_income']
num_columns_for_bin = ['age']

# %%
# Создаем трансформеры для переменных
# Категориальные, как и говорилось ранее будем кодировать
# Количественные преобразуем силовым преобразованием Йео-Джонсона и стандартизируем
# Переменную возраст разобьем на группы с помощью биннинга

cat_pipe = Pipeline([('ohe', OneHotEncoder(sparse = False, handle_unknown = 'ignore'))])
num_pipe = Pipeline([('yeo-johnson', PowerTransformer('yeo-johnson')), ('std', StandardScaler())])
num_bin_pipe = Pipeline([('bin', KBinsDiscretizer())])

# %%
# Создаем список кортежей, в котором первый элемент кортежа - название трансформера с преобразованиями

transformers = [('num_bin', num_bin_pipe, num_columns_for_bin), ('cat', cat_pipe, cat_columns), ('num', num_pipe, num_columns)]

# %%
# Передаем список в ColumnTransformer

ct = ColumnTransformer(transformers = transformers)

# %%
# В качестве модели выберем логистическую регрессию

from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# Задаем итоговый конвейер

ml_pipe = Pipeline([('transform', ct), ('logreg', LogisticRegression(solver = 'saga'))])

# %%
# И сетку параметров

param_grid = {'transform__num_bin__bin__n_bins': [3, 4, 5], 
              'transform__num_bin__bin__strategy': ['uniform', 'quantile', 'kmeans'], 
              'logreg__C': [.01, .1, .5, 1, 5, 10]}

# %%
# Используем кросс-валидацию по времени

tscv = TimeSeriesSplit(n_splits = 5)

# %%
# Создадим экземпляр класса GridSearchCV

gs = GridSearchCV(ml_pipe, param_grid, cv = tscv, return_train_score = False)

# %%
# Обучим модель на тренировочных данных и посмотрим лучший найденный набор параметров 

gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=5),
#              estimator=Pipeline(steps=[('transform',
#                                         ColumnTransformer(transformers=[('num_bin',
#                                                                          Pipeline(steps=[('bin',
#                                                                                           KBinsDiscretizer())]),
#                                                                          ['age']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse=False))]),
#                                                                          ['gender']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('yeo-johnson',
#                                                                                           PowerTransforme...
#                                                                           'active_cred_sum_overdue',
#                                                                           'active_cred_sum',
#                                                                           'active_cred_day_overdue',
#                                                                           'active_cred_max_overdue',
#                                                                           'first_loan',
#                                                                           'first_days_quant',
#                                                                           'month_income'])])),
#                                        ('logreg',
#                                         LogisticRegression(solver='saga'))]),
#              param_grid={'logreg__C': [0.01, 0.1, 0.5, 1, 5, 10],
#                          'transform__num_bin__bin__n_bins': [3, 4, 5],
#                          'transform__num_bin__bin__strategy': ['uniform',
#                                                                'quantile',
#                                                                'kmeans']})

# %%
gs.best_params_
# Out:
# {'logreg__C': 0.5,
#  'transform__num_bin__bin__n_bins': 5,
#  'transform__num_bin__bin__strategy': 'kmeans'}

# %%
y_pred = gs.predict(X_test)

# %%
metrics.plot_confusion_matrix(gs, X_test, y_test)
plt.show()

# %%
metrics.classification_report(y_pred, y_test, output_dict = True)
# Out:
# {'0': {'precision': 0.47405828002842926,
#   'recall': 0.6710261569416499,
#   'f1-score': 0.5556018325697626,
#   'support': 1988},
#  '1': {'precision': 0.9174450896238323,
#   'recall': 0.8308184727937814,
#   'f1-score': 0.8719856028794241,
#   'support': 8748},
#  'accuracy': 0.8012295081967213,
#  'macro avg': {'precision': 0.6957516848261308,
#   'recall': 0.7509223148677157,
#   'f1-score': 0.7137937177245933,
#   'support': 10736},
#  'weighted avg': {'precision': 0.8353425395608982,
#   'recall': 0.8012295081967213,
#   'f1-score': 0.8134003816261075,
#   'support': 10736}}

# %%
# Чтобы избежать ошибок 1-го рода(одобрить кредит заемщику, который его не вернет)
# и ошибок 2-го рода(отклонить кредит ответственному заемщику) нам нужно не строго классифицировать целевую переменную,
# а ранжировать вероятности классификации
# Для этого построим метрики качества, не зависящие от порога, такие как Gini и AUC-ROC

auc = metrics.roc_auc_score(y_test, gs.predict_proba(X_test)[::,1])
auc
# Out:
# 0.8388084687465402

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, gs.predict_proba(X_test)[::,1])

# %%
plt.plot(fpr, tpr, label = "data_pre, auc = "+str(auc))
plt.legend(loc=4)
plt.show()

# %%
Gini = 2 * auc - 1
Gini
# Out:
# 0.6776169374930805

# %%
print('Площадь под ROC-кривой = ', auc)
print('Коэффициент Джини = ', Gini)
# Out:
# Площадь под ROC-кривой =  0.8388084687465402
# Коэффициент Джини =  0.6776169374930805
